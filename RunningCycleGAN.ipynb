# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# fatal: destination path 'pytorch-CycleGAN-and-pix2pix' already exists and is not an empty directory.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt

# %%
import torch
torch.cuda.set_device(0)

# %%
# !python test.py --dataroot datasets/foggy/testA --name foggy --model test --no_dropout --num_test 12630
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/foggy/testA          	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: foggy                         	[default: experiment_name]
#                       ndf: 64
# ...

# %%
import os
import numpy as np
from PIL import Image


pathNew = "C:/Users/maxwr/pytorch-CycleGAN-and-pix2pix/results/foggy/test_latest/images"
fakeImgPaths = [os.path.join(pathNew, file) for file in os.listdir(pathNew) if file.endswith("_fake.png")]

image_arrays = [np.array(Image.open(img_path)) for img_path in fakeImgPaths]

np.save("foggyCycleGAN.npy",np.array(image_arrays))
print("Done")
# Out:
# Done
